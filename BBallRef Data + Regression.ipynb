# %%
# %reset -fs
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('betting_data.csv')

# %%
len(df)
# Out:
# 4626

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#             Date             Name Team Position  Opp Home/Away  Line  \
# 0     2021-10-21           Bogdan  ATL        G  DAL       vs.  15.5
# 1     2021-10-23           Bogdan  ATL        G  CLE         @  14.5
# 2     2021-10-25           Bogdan  ATL        G  DET       vs.  15.5
# 3     2021-10-28           Bogdan  ATL        G  WAS         @  12.5
# 4     2021-10-30           Bogdan  ATL        G  PHI         @  12.5
# ...          ...              ...  ...      ...  ...       ...   ...
# 4621  2021-12-04       Zeke Nnaji  DEN        F  NYK         @   5.5
# 4622  2021-12-06       Zeke Nnaji  DEN        F  CHI         @   7.5
# 4623  2021-10-28  Ziaire Williams  MEM        G  GSW         @   5.5
# 4624  2022-01-17  Ziaire Williams  MEM        G  CHI       vs.   8.5
# 4625  2022-01-23  Ziaire Williams  MEM        G  DAL         @  10.5
#
#       Moneyline  Projection  Diff  Pick  Result pick_over_under  \
# 0          -115       16.57  1.07  16.0      11               o
# ...
