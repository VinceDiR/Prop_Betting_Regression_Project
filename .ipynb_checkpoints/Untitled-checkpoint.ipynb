# %%
# %reset -fs
import pandas as pd
import seaborn as sns
import requests
import time, os
from bs4 import BeautifulSoup
import datetime
from datetime import date
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
chromedriver = "/Applications/chromedriver"
os.environ['webdriver.chrome.driver'] = chromedriver

# %%
driver = webdriver.Chrome(chromedriver)

# %%
prop_bets = {}

bet_search =  'https://www.bettingpros.com/nba/picks/prop-bets/bet/points/'
query = '?date=' + datetime.date.today().strftime('%Y-%m-%d')
bet_query = bet_search + query
response = requests.get(bet_query)
page = response.text
driver.get(bet_query)
#print(driver.page_source)
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
table = soup.find('table')
table_header_data = table.find_all('tr')

# %%
headers = []
for th in table_header_data[0].find_all('th'):
    headers.append(th.text.replace('\n', ' ').strip())
headers
# Out:
# ['RK',
#  'Player',
#  'Opp',
#  'Stat',
#  'O/U Line',
#  'Projection',
#  'Diff',
#  'Pick',
#  'Pick']

# %%
table_data = table.tbody.find_all('tr')
data_str = []
data = []
for tr in table_data:
    data_str.append(tr.text.replace('\n', ' ').strip())
for i in data_str:
    li = list(i.split('            '))
    data.append(li)
data
df = pd.DataFrame(data, )
df
# Out:
#                                 0        1        2                3  \
# 0              1 L. LeBron  James  LAL - F    @ ORL           Points
# 1             2 S. Stephen  Curry  GSW - G  vs. HOU           Points
# 2              3 J. James  Harden  BKN - G    @ SAS           Points
# 3               4 J. Joel  Embiid  PHI - C  vs. LAC           Points
# 4            5 B. Brandon  Clarke  MEM - F    @ DEN           Points
# 5             6 M. Miles  Bridges  CHA - F  vs. OKC           Points
# 6               7 C. Cory  Joseph  DET - G    @ UTH           Points
# 7             8 D. Derrick  White  SAS - G  vs. BKN           Points
# 8            9 G. Gary  Payton II  GSW - G  vs. HOU           Points
# 9             10 K. Kelly  Olynyk  DET - F    @ UTH           Points
# 10               11 J. Ja  Morant  MEM - G    @ DEN           Points
# 11       12 S. Spencer  Dinwiddie  WAS - G  vs. TOR           Points
# 12         13 D. Dennis  Schroder  BOS - G  vs. POR           Points
# 13             14 B. Bam  Adebayo  MIA - C    @ ATL           Points
# 14         15 P. P.J.  Washington  CHA - F  vs. OKC           Points
# 15             16 C. CJ  McCollum  POR - G    @ BOS           Points
# 16         17 A. Anfernee  Simons  POR - G    @ BOS           Points
# 17         18 C. Carmelo  Anthony  LAL - F    @ ORL           Points
# 18         19 D. Dejounte  Murray  SAS - G  vs. BKN           Points
# 19          20 N. Nikola  Vucevic  CHI - C    @ MIL           Points
# 20            21 J. Josh  Jackson  DET - G    @ UTH           Points
# 21            22 T. Terry  Rozier  CHA - G  vs. OKC           Points
# 22             23 R. Rudy  Gobert  UTH - C  vs. DET           Points
# 23            24 J. John  Collins  ATL - F  vs. MIA           Points
# 24       25 M. Marcus  Morris Sr.  LAC - F    @ PHI           Points
# 25            26 B. Bradley  Beal  WAS - G  vs. TOR           Points
# 26            27 J. Jayson  Tatum  BOS - F  vs. POR           Points
# 27             28 A. Amir  Coffey  LAC - G    @ PHI           Points
# 28     29 T. Talen  Horton-Tucker  LAL - G    @ ORL           Points
# 29             30 G. Gary  Harris  ORL - G  vs. LAL           Points
# 30           31 K. Kevin  Huerter  ATL - G  vs. MIA           Points
# 31           32 J. Jae'Sean  Tate  HOU - F    @ GSW           Points
# 32        33 J. Jonathan  Kuminga  GSW - F  vs. HOU           Points
# 33       34 J. Jaren  Jackson Jr.  MEM - F    @ DEN           Points
# 34        35 R. Robert  Covington  POR - F    @ BOS           Points
# 35              36 M. Malik  Monk  LAL - G    @ ORL           Points
# 36            37 J. Jordan  Poole  GSW - G  vs. HOU           Points
# 37         38 J. Jalen  McDaniels  CHA - F  vs. OKC           Points
# 38          39 R. Reggie  Jackson  LAC - G    @ PHI           Points
# 39         40 J. Jordan  Clarkson  UTH - G  vs. DET           Points
# 40       41 L. LaMarcus  Aldridge  BKN - C    @ SAS           Points
# 41          42 F. Furkan  Korkmaz  PHI - G  vs. LAC           Points
# 42              43 O. OG  Anunoby  TOR - F    @ WAS           Points
# 43          44 A. Andrew  Wiggins  GSW - F  vs. HOU           Points
# 44              45 C. Coby  White  CHI - G    @ MIL           Points
# 45               46 M. Max  Strus  MIA - G    @ ATL           Points
# 46  47 J. Jeremiah  Robinson-Earl  OKC - F    @ CHA           Points
# 47           48 M. Mason  Plumlee  CHA - F  vs. OKC           Points
# 48   49 R. Russell  Westbrook III  LAL - G    @ ORL           Points
# 49            50 J. Jaylen  Brown  BOS - G  vs. POR           Points
#
#                                                     4
# 0          31.50 (-125)26.10Diff: -5.40 Line: 31.5...
# 1          25.50 (-115)29.80Diff: 4.30 Line: 25.50...
# 2          26.50 (-125)22.50Diff: -4.00 Line: 26.5...
# 3          31.50 (-130)27.50Diff: -4.00 Line: 31.5...
# 4          12.50 (-105)8.80Diff: -3.70 Line: 12.50...
# 5          20.50 (-120)16.80Diff: -3.70 Line: 20.5...
# 6          11.50 (-111)7.80Diff: -3.70 Line: 11.50...
# 7          17.50 (-125)14.10Diff: -3.40 Line: 17.5...
# 8          7.50 (-115)10.80Diff: 3.30 Line: 7.50 C...
# 9          12.50 (-111)9.40Diff: -3.10 Line: 12.50...
# 10         27.50 (-120)24.50Diff: -3.00 Line: 27.5...
# 11         12.50 (-118)15.50Diff: 3.00 Line: 12.50...
# 12         15.50 (-120)18.50Diff: 3.00 Line: 15.50...
# 13         16.50 (-111)19.50Diff: 3.00 Line: 16.50...
# 14         7.50 (-125)10.50Diff: 3.00 Line: 7.50 C...
# 15         18.50 (-128)21.40Diff: 2.90 Line: 18.50...
# 16         19.50 (-113)16.70Diff: -2.80 Line: 19.5...
# 17         11.50 (-105)14.30Diff: 2.80 Line: 11.50...
# 18         20.50 (+105)17.80Diff: -2.70 Line: 20.5...
# 19         19.50 (-128)16.80Diff: -2.70 Line: 19.5...
# 20         7.50 (-105)4.80Diff: -2.70 Line: 7.50 C...
# 21         20.50 (-110)17.90Diff: -2.60 Line: 20.5...
# 22         18.50 (-125)16.00Diff: -2.50 Line: 18.5...
# 23         15.50 (-125)17.91Diff: 2.41 Line: 15.50...
# 24         17.50 (-120)15.16Diff: -2.34 Line: 17.5...
# 25         24.50 (-130)22.20Diff: -2.30 Line: 24.5...
# 26         25.50 (-118)27.80Diff: 2.30 Line: 25.50...
# 27         9.50 (-113)11.80Diff: 2.30 Line: 9.50 C...
# 28         9.50 (-120)11.80Diff: 2.30 Line: 9.50 C...
# 29         10.50 (-115)12.70Diff: 2.20 Line: 10.50...
# 30         13.50 (-105)11.38Diff: -2.12 Line: 13.5...
# 31         12.50 (-104)10.40Diff: -2.10 Line: 12.5...
# 32         12.50 (-125)14.60Diff: 2.10 Line: 12.50...
# 33         17.50 (+102)15.40Diff: -2.10 Line: 17.5...
# 34         9.50 (-125)7.40Diff: -2.10 Line: 9.50 C...
# 35         12.50 (-105)14.60Diff: 2.10 Line: 12.50...
# 36         16.50 (-107)18.60Diff: 2.10 Line: 16.50...
# 37         6.50 (-125)4.50Diff: -2.00 Line: 6.50 C...
# 38         16.50 (-115)14.50Diff: -2.00 Line: 16.5...
# 39         19.50 (-118)17.60Diff: -1.90 Line: 19.5...
# 40         12.50 (-115)14.40Diff: 1.90 Line: 12.50...
# 41         11.50 (-110)13.40Diff: 1.90 Line: 11.50...
# 42         17.50 (-128)19.36Diff: 1.86 Line: 17.50...
# 43         17.50 (-113)19.30Diff: 1.80 Line: 17.50...
# 44         17.50 (-105)15.70Diff: -1.80 Line: 17.5...
# 45         12.50 (-115)14.30Diff: 1.80 Line: 12.50...
# 46         7.50 (-113)9.30Diff: 1.80 Line: 7.50 Co...
# 47         6.50 (-113)8.30Diff: 1.80 Line: 6.50 Co...
# 48         16.50 (-120)18.30Diff: 1.80 Line: 16.50...
# 49         23.50 (-122)25.20Diff: 1.70 Line: 23.50...

# %%
base = datetime.datetime.today()
delta = base - datetime.datetime(2021, 10, 19)
date_list = [base - datetime.timedelta(days=x) for x in range(delta.days+1)]
date_list = [d.strftime('%Y-%m-%d') for d in date_list]
date_list
# Out:
# ['2022-01-21',
#  '2022-01-20',
#  '2022-01-19',
#  '2022-01-18',
#  '2022-01-17',
#  '2022-01-16',
#  '2022-01-15',
#  '2022-01-14',
#  '2022-01-13',
#  '2022-01-12',
#  '2022-01-11',
#  '2022-01-10',
#  '2022-01-09',
#  '2022-01-08',
#  '2022-01-07',
#  '2022-01-06',
#  '2022-01-05',
#  '2022-01-04',
#  '2022-01-03',
#  '2022-01-02',
#  '2022-01-01',
#  '2021-12-31',
#  '2021-12-30',
#  '2021-12-29',
#  '2021-12-28',
#  '2021-12-27',
#  '2021-12-26',
#  '2021-12-25',
#  '2021-12-24',
#  '2021-12-23',
#  '2021-12-22',
#  '2021-12-21',
#  '2021-12-20',
#  '2021-12-19',
#  '2021-12-18',
#  '2021-12-17',
#  '2021-12-16',
#  '2021-12-15',
#  '2021-12-14',
#  '2021-12-13',
#  '2021-12-12',
#  '2021-12-11',
#  '2021-12-10',
#  '2021-12-09',
#  '2021-12-08',
#  '2021-12-07',
#  '2021-12-06',
#  '2021-12-05',
#  '2021-12-04',
#  '2021-12-03',
#  '2021-12-02',
#  '2021-12-01',
#  '2021-11-30',
#  '2021-11-29',
#  '2021-11-28',
#  '2021-11-27',
#  '2021-11-26',
#  '2021-11-25',
#  '2021-11-24',
#  '2021-11-23',
#  '2021-11-22',
#  '2021-11-21',
#  '2021-11-20',
#  '2021-11-19',
#  '2021-11-18',
#  '2021-11-17',
#  '2021-11-16',
#  '2021-11-15',
#  '2021-11-14',
#  '2021-11-13',
#  '2021-11-12',
#  '2021-11-11',
#  '2021-11-10',
#  '2021-11-09',
#  '2021-11-08',
#  '2021-11-07',
#  '2021-11-06',
#  '2021-11-05',
#  '2021-11-04',
#  '2021-11-03',
#  '2021-11-02',
#  '2021-11-01',
#  '2021-10-31',
#  '2021-10-30',
#  '2021-10-29',
#  '2021-10-28',
#  '2021-10-27',
#  '2021-10-26',
#  '2021-10-25',
#  '2021-10-24',
#  '2021-10-23',
#  '2021-10-22',
#  '2021-10-21',
#  '2021-10-20',
#  '2021-10-19']

# %%
for i in date_list:
    url = bet_search + '?date=' + i
    response = requests.get(url)
    page = response.text

# %%
def get_betting_table(date):
    bet_url =  'https://www.bettingpros.com/nba/picks/prop-bets/bet/points/'
    query_string = '?date=' + datetime.date.today().strftime('%Y-%m-%d')
    url = bet_search + query
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, 'lxml')
    table = soup.find('table')

# %%
driver.page_source[:1000]
# Out:
# '<html lang="en"><head>\n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n        <link rel="canonical" href="https://www.bettingpros.com/nba/picks/prop-bets/bet/points/">\n    <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700,800%7CRaleway:400,500,600,700,800%7CTitillium+Web:200,400,600,700&amp;subset=cyrillic,cyrillic-ext,greek,latin-ext,vietnamese" rel="stylesheet">\n    <link rel="stylesheet" href="/assets/css/min/stylesheet-8f65062da6677a86d71694843b3c50d6.css">\n    <link rel="icon" type="image/x-icon" href="/assets/images/favicon.ico">\n\n            <meta name="apple-itunes-app" content="app-id=1468109182, app-argument=https://www.bettingpros.com/nba/picks/prop-bets/bet/points/">\n        <script crossorigin="anonymous" src="https://surveys-static.survicate.com/widget_core-13.5.6.js" async=""></script><script src="https://partner.googleadservices.com/gampad/cookie.js?domain=www.bettingpros.com&amp;callback=_gfp_'

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
