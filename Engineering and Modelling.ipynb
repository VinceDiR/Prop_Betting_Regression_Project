# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

# %%
df = pd.read_csv('player_team_stats_merged.csv', index_col=0)
df
# Out:
#                 Player     Age Pos   Tm Home/Away_x  Opp Game Result  \
# 0         Aaron Gordon  26-034   F  DEN        Away  PHO           W
# 1         Aaron Gordon  26-036   F  DEN        Home  SAS           W
# 2         Aaron Gordon  26-039   F  DEN        Home  CLE           L
# 3         Aaron Gordon  26-040   F  DEN        Away  UTA           L
# 4         Aaron Gordon  26-043   F  DEN        Home  DAL           W
# ...                ...     ...  ..  ...         ...  ...         ...
# 14997  Ziaire Williams  20-127   F  MEM        Home  CHI           W
# 14998  Ziaire Williams  20-129   F  MEM        Away  MIL           L
# 14999  Ziaire Williams  20-131   F  MEM        Away  DEN           W
# 15000  Ziaire Williams  20-133   F  MEM        Away  DAL           L
# 15001   Zylan Cheatham  26-056   F  UTA        Home  CLE           L
#
#              Date  GS  MP_x  FG_x  FGA_x  FG%_x  2P_x  2PA_x  2P%_x  3P_x  \
# 0      2021-10-20   1    29     5      6  0.833     4      5  0.800     1
# 1      2021-10-22   1    30     3      6  0.500     3      5  0.600     0
# 2      2021-10-25   1    28     5     14  0.357     4      9  0.444     1
# 3      2021-10-26   1    34     9     13  0.692     9     10  0.900     0
# 4      2021-10-29   1    24     6      9  0.667     5      7  0.714     1
# ...           ...  ..   ...   ...    ...    ...   ...    ...    ...   ...
# 14997  2022-01-17   1    18     0      4  0.000     0      1  0.000     0
# 14998  2022-01-19   1    33     4     11  0.364     3      4  0.750     1
# 14999  2022-01-21   1    31     6      8  0.750     4      5  0.800     2
# 15000  2022-01-23   1    23     4     13  0.308     3      5  0.600     1
# 15001  2022-01-12   0     5     0      3  0.000     0      1  0.000     0
#
#        3PA_x  3P%_x  FT_x  FTA_x  FT%_x    TS%  ORB  DRB  TRB  AST  STL  BLK  \
# 0          1  1.000     1      2   0.50  0.872    2    6    8    4    0    1
# 1          1  0.000     2      2   1.00  0.581    2    3    5    1    0    0
# 2          5  0.200     1      2   0.50  0.403    3    6    9    1    0    0
# 3          3  0.000     2      4   0.50  0.678    1    6    7    1    1    1
# 4          2  0.500     0      1   0.00  0.689    1    4    5    2    1    1
# ...      ...    ...   ...    ...    ...    ...  ...  ...  ...  ...  ...  ...
# 14997      3  0.000     2      2   1.00  0.205    0    3    3    1    0    0
# 14998      7  0.143     1      1   1.00  0.437    0    1    1    1    1    0
# 14999      3  0.667     3      4   0.75  0.871    1    4    5    0    2    1
# 15000      8  0.125     0      0    NaN  0.346    1    0    1    1    0    0
# 15001      2  0.000     0      0    NaN  0.000    0    0    0    0    0    0
#
#        TOV  PF  PTS_x  GmSc   BPM Home/Away_y     Result  MP_y  FG_y  FGA_y  \
# 0        3   2     12  12.3   6.1        Away   W 110-98   240    44     83
# 1        3   5      8   3.0  -8.1        Home   W 102-96   240    44     86
# 2        3   2     12   4.6  -6.5        Home    L 87-99   240    35     86
# 3        4   5     20  12.6  -3.2        Away  L 110-122   240    42     83
# 4        2   1     13  11.3   8.3        Home   W 106-75   240    43     83
# ...    ...  ..    ...   ...   ...         ...        ...   ...   ...    ...
# 14997    2   2      2  -2.0 -17.9        Home  W 119-106   240    47     92
# 14998    0   1     10   5.5  -6.3        Away  L 114-126   240    44    106
# 14999    0   4     17  16.4   8.1        Away  W 122-118   240    43     82
# 15000    0   5      9   0.9  -9.6        Away   L 91-104   240    37     99
# 15001    0   0      0  -2.1 -30.2        Home   L 91-111   240    34     85
#
#        FG%_y  2P_y  2PA_y  2P%_y  3P_y  3PA_y  3P%_y  FT_y  FTA_y  FT%_y  \
# 0      0.530    27     44  0.614    17     39  0.436     5      9  0.556
# 1      0.512    35     56  0.625     9     30  0.300     5      8  0.625
# 2      0.407    26     48  0.542     9     38  0.237     8     12  0.667
# 3      0.506    32     55  0.582    10     28  0.357    16     24  0.667
# 4      0.518    32     47  0.681    11     36  0.306     9     13  0.692
# ...      ...   ...    ...    ...   ...    ...    ...   ...    ...    ...
# 14997  0.511    37     67  0.552    10     25  0.400    15     20  0.750
# 14998  0.415    35     66  0.530     9     40  0.225    17     25  0.680
# 14999  0.524    32     57  0.561    11     25  0.440    25     40  0.625
# 15000  0.374    33     75  0.440     4     24  0.167    13     19  0.684
# 15001  0.400    18     38  0.474    16     47  0.340     7     11  0.636
#
#        PTS_y  FG.1  FGA.1  FG%.1  2P.1  2PA.1  2P%.1  3P.1  3PA.1  3P%.1  \
# 0        110    36     87  0.414    22     50  0.440    14     37  0.378
# 1        102    40     84  0.476    34     60  0.567     6     24  0.250
# 2         87    38     82  0.463    31     57  0.544     7     25  0.280
# 3        110    44     85  0.518    32     46  0.696    12     39  0.308
# 4        106    23     78  0.295    15     41  0.366     8     37  0.216
# ...      ...   ...    ...    ...   ...    ...    ...   ...    ...    ...
# 14997    119    40     92  0.435    27     61  0.443    13     31  0.419
# 14998    114    46     97  0.474    33     60  0.550    13     37  0.351
# 14999    122    43     91  0.473    30     59  0.508    13     32  0.406
# 15000     91    36     74  0.486    27     44  0.614     9     30  0.300
# 15001     91    43     81  0.531    32     51  0.627    11     30  0.367
#
#        FT.1  FTA.1  FT%.1  PTS.1
# 0        12     17  0.706     98
# 1        10     14  0.714     96
# 2        16     20  0.800     99
# 3        22     29  0.759    122
# 4        21     27  0.778     75
# ...     ...    ...    ...    ...
# 14997    13     15  0.867    106
# 14998    21     22  0.955    126
# 14999    19     23  0.826    118
# 15000    23     31  0.742    104
# 15001    14     17  0.824    111
#
# [15002 rows x 63 columns]

# %%
df.Date = pd.to_datetime(df.Date)

# %%
df['days_rest'] = df.groupby(['Player', 'Date'])['Date'].apply(lambda x: x.diff())
df
# Out:
#                 Player     Age Pos   Tm Home/Away_x  Opp Game Result  \
# 0         Aaron Gordon  26-034   F  DEN        Away  PHO           W
# 1         Aaron Gordon  26-036   F  DEN        Home  SAS           W
# 2         Aaron Gordon  26-039   F  DEN        Home  CLE           L
# 3         Aaron Gordon  26-040   F  DEN        Away  UTA           L
# 4         Aaron Gordon  26-043   F  DEN        Home  DAL           W
# ...                ...     ...  ..  ...         ...  ...         ...
# 14997  Ziaire Williams  20-127   F  MEM        Home  CHI           W
# 14998  Ziaire Williams  20-129   F  MEM        Away  MIL           L
# 14999  Ziaire Williams  20-131   F  MEM        Away  DEN           W
# 15000  Ziaire Williams  20-133   F  MEM        Away  DAL           L
# 15001   Zylan Cheatham  26-056   F  UTA        Home  CLE           L
#
#             Date  GS  MP_x  FG_x  FGA_x  FG%_x  2P_x  2PA_x  2P%_x  3P_x  \
# 0     2021-10-20   1    29     5      6  0.833     4      5  0.800     1
# 1     2021-10-22   1    30     3      6  0.500     3      5  0.600     0
# 2     2021-10-25   1    28     5     14  0.357     4      9  0.444     1
# 3     2021-10-26   1    34     9     13  0.692     9     10  0.900     0
# 4     2021-10-29   1    24     6      9  0.667     5      7  0.714     1
# ...          ...  ..   ...   ...    ...    ...   ...    ...    ...   ...
# 14997 2022-01-17   1    18     0      4  0.000     0      1  0.000     0
# 14998 2022-01-19   1    33     4     11  0.364     3      4  0.750     1
# 14999 2022-01-21   1    31     6      8  0.750     4      5  0.800     2
# 15000 2022-01-23   1    23     4     13  0.308     3      5  0.600     1
# 15001 2022-01-12   0     5     0      3  0.000     0      1  0.000     0
#
#        3PA_x  3P%_x  FT_x  FTA_x  FT%_x    TS%  ORB  DRB  TRB  AST  STL  BLK  \
# 0          1  1.000     1      2   0.50  0.872    2    6    8    4    0    1
# 1          1  0.000     2      2   1.00  0.581    2    3    5    1    0    0
# 2          5  0.200     1      2   0.50  0.403    3    6    9    1    0    0
# 3          3  0.000     2      4   0.50  0.678    1    6    7    1    1    1
# 4          2  0.500     0      1   0.00  0.689    1    4    5    2    1    1
# ...      ...    ...   ...    ...    ...    ...  ...  ...  ...  ...  ...  ...
# 14997      3  0.000     2      2   1.00  0.205    0    3    3    1    0    0
# 14998      7  0.143     1      1   1.00  0.437    0    1    1    1    1    0
# 14999      3  0.667     3      4   0.75  0.871    1    4    5    0    2    1
# 15000      8  0.125     0      0    NaN  0.346    1    0    1    1    0    0
# 15001      2  0.000     0      0    NaN  0.000    0    0    0    0    0    0
#
#        TOV  PF  PTS_x  GmSc   BPM Home/Away_y     Result  MP_y  FG_y  FGA_y  \
# 0        3   2     12  12.3   6.1        Away   W 110-98   240    44     83
# 1        3   5      8   3.0  -8.1        Home   W 102-96   240    44     86
# 2        3   2     12   4.6  -6.5        Home    L 87-99   240    35     86
# 3        4   5     20  12.6  -3.2        Away  L 110-122   240    42     83
# 4        2   1     13  11.3   8.3        Home   W 106-75   240    43     83
# ...    ...  ..    ...   ...   ...         ...        ...   ...   ...    ...
# 14997    2   2      2  -2.0 -17.9        Home  W 119-106   240    47     92
# 14998    0   1     10   5.5  -6.3        Away  L 114-126   240    44    106
# 14999    0   4     17  16.4   8.1        Away  W 122-118   240    43     82
# 15000    0   5      9   0.9  -9.6        Away   L 91-104   240    37     99
# 15001    0   0      0  -2.1 -30.2        Home   L 91-111   240    34     85
#
#        FG%_y  2P_y  2PA_y  2P%_y  3P_y  3PA_y  3P%_y  FT_y  FTA_y  FT%_y  \
# 0      0.530    27     44  0.614    17     39  0.436     5      9  0.556
# 1      0.512    35     56  0.625     9     30  0.300     5      8  0.625
# 2      0.407    26     48  0.542     9     38  0.237     8     12  0.667
# 3      0.506    32     55  0.582    10     28  0.357    16     24  0.667
# 4      0.518    32     47  0.681    11     36  0.306     9     13  0.692
# ...      ...   ...    ...    ...   ...    ...    ...   ...    ...    ...
# 14997  0.511    37     67  0.552    10     25  0.400    15     20  0.750
# 14998  0.415    35     66  0.530     9     40  0.225    17     25  0.680
# 14999  0.524    32     57  0.561    11     25  0.440    25     40  0.625
# 15000  0.374    33     75  0.440     4     24  0.167    13     19  0.684
# 15001  0.400    18     38  0.474    16     47  0.340     7     11  0.636
#
#        PTS_y  FG.1  FGA.1  FG%.1  2P.1  2PA.1  2P%.1  3P.1  3PA.1  3P%.1  \
# 0        110    36     87  0.414    22     50  0.440    14     37  0.378
# 1        102    40     84  0.476    34     60  0.567     6     24  0.250
# 2         87    38     82  0.463    31     57  0.544     7     25  0.280
# 3        110    44     85  0.518    32     46  0.696    12     39  0.308
# 4        106    23     78  0.295    15     41  0.366     8     37  0.216
# ...      ...   ...    ...    ...   ...    ...    ...   ...    ...    ...
# 14997    119    40     92  0.435    27     61  0.443    13     31  0.419
# 14998    114    46     97  0.474    33     60  0.550    13     37  0.351
# 14999    122    43     91  0.473    30     59  0.508    13     32  0.406
# 15000     91    36     74  0.486    27     44  0.614     9     30  0.300
# 15001     91    43     81  0.531    32     51  0.627    11     30  0.367
#
#        FT.1  FTA.1  FT%.1  PTS.1 days_rest
# 0        12     17  0.706     98       NaT
# 1        10     14  0.714     96       NaT
# 2        16     20  0.800     99       NaT
# 3        22     29  0.759    122       NaT
# 4        21     27  0.778     75       NaT
# ...     ...    ...    ...    ...       ...
# 14997    13     15  0.867    106       NaT
# 14998    21     22  0.955    126       NaT
# 14999    19     23  0.826    118       NaT
# 15000    23     31  0.742    104       NaT
# 15001    14     17  0.824    111       NaT
#
# [15002 rows x 64 columns]

# %%
df['rolling_avg'] = df.PTS_x.
